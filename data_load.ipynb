# %%
import pandas as pd

# %%
df = pd.read_csv('movie-review.csv')
df
# Out:
#                        title  \
# 0            Monsoon Wedding
# 1            Monsoon Wedding
# 2            Monsoon Wedding
# 3            Monsoon Wedding
# 4            Monsoon Wedding
# ...                      ...
# 276921  The Invisible Circus
# 276922  The Invisible Circus
# 276923  The Invisible Circus
# 276924  The Invisible Circus
# 276925  The Invisible Circus
#
#                                                    review sentimentScore
# 0       MONSOON WEDDING is a wonderful film in which m...       POSITIVE
# 1       A celebration of life that acknowledges how fa...       POSITIVE
# 2       Not content to merely direct traffic of inters...       POSITIVE
# 3                   ... among the most universal of films       POSITIVE
# 4       A big, galloping party movie in which the part...       POSITIVE
# ...                                                   ...            ...
# 276921  When flashbacks tease us with bits of informat...       NEGATIVE
# ...

# %%
df = df.dropna()
df
# Out:
#                        title  \
# 0            Monsoon Wedding
# 1            Monsoon Wedding
# 2            Monsoon Wedding
# 3            Monsoon Wedding
# 4            Monsoon Wedding
# ...                      ...
# 276921  The Invisible Circus
# 276922  The Invisible Circus
# 276923  The Invisible Circus
# 276924  The Invisible Circus
# 276925  The Invisible Circus
#
#                                                    review sentimentScore
# 0       MONSOON WEDDING is a wonderful film in which m...       POSITIVE
# 1       A celebration of life that acknowledges how fa...       POSITIVE
# 2       Not content to merely direct traffic of inters...       POSITIVE
# 3                   ... among the most universal of films       POSITIVE
# 4       A big, galloping party movie in which the part...       POSITIVE
# ...                                                   ...            ...
# 276921  When flashbacks tease us with bits of informat...       NEGATIVE
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                        title  \
# 0            Monsoon Wedding
# 1            Monsoon Wedding
# 2            Monsoon Wedding
# 3            Monsoon Wedding
# 4            Monsoon Wedding
# ...                      ...
# 276921  The Invisible Circus
# 276922  The Invisible Circus
# 276923  The Invisible Circus
# 276924  The Invisible Circus
# 276925  The Invisible Circus
#
#                                                    review sentimentScore
# 0       MONSOON WEDDING is a wonderful film in which m...       POSITIVE
# 1       A celebration of life that acknowledges how fa...       POSITIVE
# 2       Not content to merely direct traffic of inters...       POSITIVE
# 3                   ... among the most universal of films       POSITIVE
# 4       A big, galloping party movie in which the part...       POSITIVE
# ...                                                   ...            ...
# 276921  When flashbacks tease us with bits of informat...       NEGATIVE
# ...

# %%
df.to_csv('movie-review-cleaned.csv', index=False)
